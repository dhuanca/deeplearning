# %% [markdown]
# <a href="https://colab.research.google.com/github/dhuanca/deeplearning/blob/main/Implementacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configuraciones de acceso

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/utils.ipynb"
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Modelo 1
# timestep = 1
df = datasetIngestado('/content/drive/MyDrive/RetoAplicacion_TELEFBC1.csv')
rmse_1, mape_1 = genera_modelo('Close', 100, 1, 0.2, 'adam', 'mean_squared_error', 50, 32, False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 1, 250)            252000
#
#  dropout (Dropout)           (None, 1, 250)            0
#
#  lstm_1 (LSTM)               (None, 1, 250)            501000
#
#  dropout_1 (Dropout)         (None, 1, 250)            0
#
#  lstm_2 (LSTM)               (None, 1, 250)            501000
#
#  dropout_2 (Dropout)         (None, 1, 250)            0
#
#  lstm_3 (LSTM)               (None, 250)               501000
#
#  dropout_3 (Dropout)         (None, 250)               0
#
#  dense (Dense)               (None, 1)                 251
#
# ...
# Total params: 1755251 (6.70 MB)
# Trainable params: 1755251 (6.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 55/55 [==============================] - 13s 12ms/step - loss: 0.1392
# ...

# %%
# Modelo 1 iterando batch
# timestep = 1


lista = []
for x in [32, 64, 100, 120 ,150]:
  df = datasetIngestado('/content/drive/MyDrive/RetoAplicacion_TELEFBC1.csv')
  mape = genera_modelo('Close', 100, 1, 0.2, 'adam', 'mean_squared_error', 50, x, False)
  lista.append(mape)

lista
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_64 (LSTM)              (None, 1, 250)            252000
#
#  dropout_64 (Dropout)        (None, 1, 250)            0
#
#  lstm_65 (LSTM)              (None, 1, 250)            501000
#
#  dropout_65 (Dropout)        (None, 1, 250)            0
#
#  lstm_66 (LSTM)              (None, 1, 250)            501000
#
#  dropout_66 (Dropout)        (None, 1, 250)            0
#
#  lstm_67 (LSTM)              (None, 250)               501000
#
#  dropout_67 (Dropout)        (None, 250)               0
#
#  dense_16 (Dense)            (None, 1)                 251
#
# ...
# Total params: 1755251 (6.70 MB)
# Trainable params: 1755251 (6.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 347/347 [==============================] - 10s 8ms/step - loss: 0.0253
# ...

# %%
# Modelo 2
# timestep = 7
df = datasetIngestado('/content/drive/MyDrive/RetoAplicacion_TELEFBC1.csv')
rmse_2, mape_2 = genera_modelo('Close', 100, 7, 0.2, 'adam', 'mean_squared_error', 50, 32, False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_4 (LSTM)               (None, 7, 250)            252000
#
#  dropout_4 (Dropout)         (None, 7, 250)            0
#
#  lstm_5 (LSTM)               (None, 7, 250)            501000
#
#  dropout_5 (Dropout)         (None, 7, 250)            0
#
#  lstm_6 (LSTM)               (None, 7, 250)            501000
#
#  dropout_6 (Dropout)         (None, 7, 250)            0
#
#  lstm_7 (LSTM)               (None, 250)               501000
#
#  dropout_7 (Dropout)         (None, 250)               0
#
#  dense_1 (Dense)             (None, 1)                 251
#
# ...
# Total params: 1755251 (6.70 MB)
# Trainable params: 1755251 (6.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 8s 10ms/step - loss: 0.0506
# ...

# %%
# Modelo 3
# timestep = 30
df = datasetIngestado('/content/drive/MyDrive/RetoAplicacion_TELEFBC1.csv')
rmse_3, mape_3 = genera_modelo('Close', 100, 30, 0.2, 'adam', 'mean_squared_error', 50, 50, False)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_12 (LSTM)              (None, 30, 250)           252000
#
#  dropout_12 (Dropout)        (None, 30, 250)           0
#
#  lstm_13 (LSTM)              (None, 30, 250)           501000
#
#  dropout_13 (Dropout)        (None, 30, 250)           0
#
#  lstm_14 (LSTM)              (None, 30, 250)           501000
#
#  dropout_14 (Dropout)        (None, 30, 250)           0
#
#  lstm_15 (LSTM)              (None, 250)               501000
#
#  dropout_15 (Dropout)        (None, 250)               0
#
#  dense_3 (Dense)             (None, 1)                 251
#
# ...
# Total params: 1755251 (6.70 MB)
# Trainable params: 1755251 (6.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 35/35 [==============================] - 8s 17ms/step - loss: 0.0569
# ...

# %%
# Modelo 6
# timestep = 1
# pred
df = datasetIngestado('/content/drive/MyDrive/RetoAplicacion_TELEFBC1.csv')
rmse_6, mape_6 = genera_modelo_con_preds('Close', 100, 1, 0.2, 'adam', 'mean_squared_error', 50, 32, False,5)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_28 (LSTM)              (None, 1, 250)            252000
#
#  dropout_28 (Dropout)        (None, 1, 250)            0
#
#  lstm_29 (LSTM)              (None, 1, 250)            501000
#
#  dropout_29 (Dropout)        (None, 1, 250)            0
#
#  lstm_30 (LSTM)              (None, 1, 250)            501000
#
#  dropout_30 (Dropout)        (None, 1, 250)            0
#
#  lstm_31 (LSTM)              (None, 250)               501000
#
#  dropout_31 (Dropout)        (None, 250)               0
#
#  dense_7 (Dense)             (None, 1)                 251
#
# ...
# Total params: 1755251 (6.70 MB)
# Trainable params: 1755251 (6.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Conclusion

# %%
# Definir datos de resultados
modelos = ['Modelo 1', 'Modelo 2', 'Modelo 3', 'Modelo 4', 'Modelo 5', 'Modelo6']
rmse = [rmse1,rmse2, rmse3, rmse4, rmse5, rmse6]
mape = [mape1, mape2, mape3, mape4, mape5,mape6 ]

# Crear DataFrames
df_configuracion = pd.DataFrame({
    'Modelo': modelos,
    'Configuración': [
        'time_steps = 1',
        'time_steps = 7',
        'time_steps = 30',
        'time_steps = 30 y 3 variables { Close, MA(3), MA(7) }',
        'time_steps = 30 y 4 Variables { Close, Volumen, MA(3), MA(7) }',
        'time_steps = 30 , pred_steps=5 y 4 Variables { Close, Volumen, MA(3), MA(7) }'
    ]
})


df_resultados = pd.DataFrame({
    'Modelo': modelos,
    'RMSE': rmse,
    'MAPE': mape
})

# Ordenar por MAPE
df_final = df_configuracion.merge(df_resultados, on='Modelo').sort_values('MAPE')

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
df_final.set_index('Modelo')[['RMSE', 'MAPE']].plot(kind='bar', rot=0)
plt.title('Gráfico de Barras de RMSE y MAPE')
plt.xlabel('Modelo')
plt.ylabel('Valor')
plt.legend(loc='upper left')
plt.show()
